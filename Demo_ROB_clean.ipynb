# %%
import pandas as pd

# Load the Excel file
df = pd.read_excel(r"C:\Users\akshat\Desktop\code\cleaned.xlsx", engine='openpyxl')

# List of columns to extract
columns_to_extract = ['Report ID', 'Report Name','Companies covered','Market Size Year 2025','CAGR','Forecast Period', 'Value Projection 2032' ]  # Replace with actual column names

# Check if the specified columns exist in the DataFrame
if all(column in df.columns for column in columns_to_extract):
    # Extract the specified columns
    extracted_columns = df[columns_to_extract]
    # Optionally, display the extracted DataFrame
    print(extracted_columns.head())  # Display the first few rows of the extracted DataFrame
else:
    missing_columns = [column for column in columns_to_extract if column not in df.columns]
    print(f"Columns {', '.join(missing_columns)} not found in the DataFrame.")
# Out:
#    Report ID                              Report Name  \
# 0          2                 Southern Blotting Market
# 1          3    Vacuum Blood Collection System Market
# 2          4                  Skin Replacement Market
# 3          5  Absorbable Nasal Implant Devices Market
# 4          6            Air Ambulance Services Market
#
#                                    Companies covered Market Size Year 2025  \
# 0                                                NaN                   NaN
# 1                                                NaN                   NaN
# 2                                                NaN                   NaN
# 3                                                NaN                   NaN
# 4  Air Methods Corporation, Deccan Charters, Scan...           USD 7.56 Bn
#
#     CAGR Forecast Period Value Projection 2032
# 0    NaN             NaN                   NaN
# 1    NaN             NaN                   NaN
# 2    NaN             NaN                   NaN
# 3    NaN             NaN                   NaN
# 4  0.096    2025 To 2032          USD 14.38 Bn

# %%
import pandas as pd

# Load the Excel file
df = pd.read_excel(r"C:\Users\akshat\Desktop\code\cleaned.xlsx", engine='openpyxl')

# List of columns to extract
columns_to_extract = ['Report ID', 'Report Name', 'Companies covered', 'Market Size Year 2025', 'CAGR', 'Forecast Period', 'Value Projection 2032']  # Replace with actual column names

# Check if the specified columns exist in the DataFrame
if all(column in df.columns for column in columns_to_extract):
    # Extract the specified columns
    extracted_columns = df[columns_to_extract]
    
    # Rename the columns
    extracted_columns.rename(columns={
        'Report Name': 'Market Name',
        'Companies covered': 'Key Players',
        'Market Size Year 2025': 'Market Size in 2025'
    }, inplace=True)

    # Set the Forecast Period column to a constant value
    extracted_columns['Forecast Period'] = '2025 to 2032'
    
    # Add a new column "Market Size Year" with constant value
    extracted_columns['Market Size Year'] = 'Market Size in 2025:'
    
    # Create the new "Market Size" column by combining "Market Size in 2025" and "Value Projection 2032"
    extracted_columns['Market Size'] = extracted_columns['Market Size in 2025'].astype(str) + '; Market Size in 2032: ' + extracted_columns['Value Projection 2032'].astype(str)
    
    # Create the "Prompt" column with the provided constant text and dynamically generated links
    extracted_columns['Prompt'] = extracted_columns.apply(
        lambda row: f"Furthermore, we have a CTA that needs to be incorporated into the generated blog. Make sure all CTAs are added properly to ensure they are fully synced with the content and, from a lead generation perspective, the placement should be optimal. CTA context: The main link redirects to our main collateral published on our website. The Sample Request URL leads to a page where users can request a sample copy of the report, and the Buy Now URL allows users to directly purchase the report by making a payment. Ensure that the CTAs are placed correctly so they direct the reader to the appropriate webpage linked. The first CTA should be placed after the Market Size and Overview data, the second CTA after the Growth Factors section, and the third CTA after the Actionable Insights. Please do not make any changes to the provided data and links such as do not add brackets, or do not make changes in formatting style, because this blog will be directly published on PR website. CTA Links: First CTA- Explore the Entire Market Report here: https://www.coherentmarketinsights.com/market-insight/{row['Market Name'].replace(' ', '-').lower()}-{row['Report ID']} , 2nd CTA- Request for Sample Copy of the Report here : https://www.coherentmarketinsights.com/insight/request-sample/{row['Report ID']} and 3rd CTA- Get Instant Access! Purchase Research Report and Receive a 25% Discount: https://www.coherentmarketinsights.com/insight/buy-now/{row['Report ID']}",
        axis=1
    )
    

    #output_df = extracted_columns['Report ID', 'Market Name', 'Key Players', 'Market Size Year', 'Market Size', 'CAGR','Forecast Period']


    print(extracted_columns.head())  # Display the first few rows of the extracted DataFrame
else:
    missing_columns = [column for column in columns_to_extract if column not in df.columns]
    print(f"Columns {', '.join(missing_columns)} not found in the DataFrame.")
# Out:
#    Report ID                              Market Name  \
# 0          2                 Southern Blotting Market
# 1          3    Vacuum Blood Collection System Market
# 2          4                  Skin Replacement Market
# 3          5  Absorbable Nasal Implant Devices Market
# 4          6            Air Ambulance Services Market
#
#                                          Key Players Market Size in 2025  \
# 0                                                NaN                 NaN
# 1                                                NaN                 NaN
# 2                                                NaN                 NaN
# 3                                                NaN                 NaN
# 4  Air Methods Corporation, Deccan Charters, Scan...         USD 7.56 Bn
#
#     CAGR Forecast Period Value Projection 2032      Market Size Year  \
# 0    NaN    2025 to 2032                   NaN  Market Size in 2025:
# 1    NaN    2025 to 2032                   NaN  Market Size in 2025:
# 2    NaN    2025 to 2032                   NaN  Market Size in 2025:
# 3    NaN    2025 to 2032                   NaN  Market Size in 2025:
# 4  0.096    2025 to 2032          USD 14.38 Bn  Market Size in 2025:
#
#                                       Market Size  \
# 0                   nan; Market Size in 2032: nan
# 1                   nan; Market Size in 2032: nan
# 2                   nan; Market Size in 2032: nan
# 3                   nan; Market Size in 2032: nan
# 4  USD 7.56 Bn; Market Size in 2032: USD 14.38 Bn
#
#                                               Prompt
# 0  Furthermore, we have a CTA that needs to be in...
# 1  Furthermore, we have a CTA that needs to be in...
# 2  Furthermore, we have a CTA that needs to be in...
# 3  Furthermore, we have a CTA that needs to be in...
# 4  Furthermore, we have a CTA that needs to be in...
# C:\Users\akshat\AppData\Local\Temp\ipykernel_16552\1228179796.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   extracted_columns.rename(columns={
# C:\Users\akshat\AppData\Local\Temp\ipykernel_16552\1228179796.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   extracted_columns['Forecast Period'] = '2025 to 2032'
# C:\Users\akshat\AppData\Local\Temp\ipykernel_16552\1228179796.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   extracted_columns['Market Size Year'] = 'Market Size in 2025:'
# C:\Users\akshat\AppData\Local\Temp\ipykernel_16552\1228179796.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   extracted_columns['Market Size'] = extracted_columns['Market Size in 2025'].astype(str) + '; Market Size in 2032: ' + extracted_columns['Value Projection 2032'].astype(str)
# C:\Users\akshat\AppData\Local\Temp\ipykernel_16552\1228179796.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   extracted_columns['Prompt'] = extracted_columns.apply(

# %%
display(extracted_columns)
# Out:
#     Report ID                                        Market Name  \
# 0           2                           Southern Blotting Market
# 1           3              Vacuum Blood Collection System Market
# 2           4                            Skin Replacement Market
# 3           5            Absorbable Nasal Implant Devices Market
# 4           6                      Air Ambulance Services Market
# ..        ...                                                ...
# 95         99                         Psoriasis Treatment Market
# 96        100                Regenerative Artificial Skin Market
# 97        101                            Vocal Biomarkers Market
# 98        102                          Car T Cell Therapy Market
# 99        103  Negative Pressure Wound Therapy (NPWT) Devices...
#
#                                           Key Players Market Size in 2025  \
# 0                                                 NaN                 NaN
# 1                                                 NaN                 NaN
# 2                                                 NaN                 NaN
# 3                                                 NaN                 NaN
# 4   Air Methods Corporation, Deccan Charters, Scan...         USD 7.56 Bn
# ..                                                ...                 ...
# 95                                                NaN                 NaN
# 96                                                NaN                 NaN
# 97                                                NaN                 NaN
# 98  Bristol-Myers Squibb Company, Johnson &amp; Jo...         USD 3.99 Bn
# 99  3M, Cardinal Health, Smith+Nephew, Genadyne, D...      USD 2,763.8 Mn
#
#      CAGR Forecast Period Value Projection 2032      Market Size Year  \
# 0     NaN    2025 to 2032                   NaN  Market Size in 2025:
# 1     NaN    2025 to 2032                   NaN  Market Size in 2025:
# 2     NaN    2025 to 2032                   NaN  Market Size in 2025:
# 3     NaN    2025 to 2032                   NaN  Market Size in 2025:
# 4   0.096    2025 to 2032          USD 14.38 Bn  Market Size in 2025:
# ..    ...             ...                   ...                   ...
# 95    NaN    2025 to 2032                   NaN  Market Size in 2025:
# 96    NaN    2025 to 2032                   NaN  Market Size in 2025:
# 97    NaN    2025 to 2032                   NaN  Market Size in 2025:
# 98  0.209    2025 to 2032          USD 15.06 Bn  Market Size in 2025:
# 99  0.065    2025 to 2032        USD 4,294.9 Mn  Market Size in 2025:
#
#                                           Market Size  \
# 0                       nan; Market Size in 2032: nan
# 1                       nan; Market Size in 2032: nan
# 2                       nan; Market Size in 2032: nan
# 3                       nan; Market Size in 2032: nan
# 4      USD 7.56 Bn; Market Size in 2032: USD 14.38 Bn
# ..                                                ...
# 95                      nan; Market Size in 2032: nan
# 96                      nan; Market Size in 2032: nan
# 97                      nan; Market Size in 2032: nan
# 98     USD 3.99 Bn; Market Size in 2032: USD 15.06 Bn
# 99  USD 2,763.8 Mn; Market Size in 2032: USD 4,294...
#
#                                                Prompt
# 0   Furthermore, we have a CTA that needs to be in...
# 1   Furthermore, we have a CTA that needs to be in...
# 2   Furthermore, we have a CTA that needs to be in...
# 3   Furthermore, we have a CTA that needs to be in...
# 4   Furthermore, we have a CTA that needs to be in...
# ..                                                ...
# 95  Furthermore, we have a CTA that needs to be in...
# 96  Furthermore, we have a CTA that needs to be in...
# 97  Furthermore, we have a CTA that needs to be in...
# 98  Furthermore, we have a CTA that needs to be in...
# 99  Furthermore, we have a CTA that needs to be in...
#
# [100 rows x 10 columns]

# %%
print(extracted_columns.loc[4, 'Prompt'])
# Out:
# Furthermore, we have a CTA that needs to be incorporated into the generated blog. Make sure all CTAs are added properly to ensure they are fully synced with the content and, from a lead generation perspective, the placement should be optimal. CTA context: The main link redirects to our main collateral published on our website. The Sample Request URL leads to a page where users can request a sample copy of the report, and the Buy Now URL allows users to directly purchase the report by making a payment. Ensure that the CTAs are placed correctly so they direct the reader to the appropriate webpage linked. The first CTA should be placed after the Market Size and Overview data, the second CTA after the Growth Factors section, and the third CTA after the Actionable Insights. Please do not make any changes to the provided data and links such as do not add brackets, or do not make changes in formatting style, because this blog will be directly published on PR website. CTA Links: First CTA- Explore the Entire Market Report here: https://www.coherentmarketinsights.com/market-insight/air-ambulance-services-market-6 , 2nd CTA- Request for Sample Copy of the Report here : https://www.coherentmarketinsights.com/insight/request-sample/6 and 3rd CTA- Get Instant Access! Purchase Research Report and Receive a 25% Discount: https://www.coherentmarketinsights.com/insight/buy-now/6

# %%
# ...existing code...
output_df = extracted_columns[['Report ID', 'Market Name', 'Key Players', 'Market Size Year', 'Market Size', 'CAGR', 'Forecast Period', 'Prompt' ]]

print(output_df.columns) 
# ...existing code...a
# Out:
# Index(['Report ID', 'Market Name', 'Key Players', 'Market Size Year',
#        'Market Size', 'CAGR', 'Forecast Period', 'Prompt'],
#       dtype='object')

# %%
desired_order = ['Report ID', 'Market Name', 'Forecast Period', 'Market Size Year','Market Size', 'CAGR', 'Key Players','Prompt' ]

# Reorder the DataFrame columns
output_df = output_df[desired_order]

display(output_df)
# Out:
#     Report ID                                        Market Name  \
# 0           2                           Southern Blotting Market
# 1           3              Vacuum Blood Collection System Market
# 2           4                            Skin Replacement Market
# 3           5            Absorbable Nasal Implant Devices Market
# 4           6                      Air Ambulance Services Market
# ..        ...                                                ...
# 95         99                         Psoriasis Treatment Market
# 96        100                Regenerative Artificial Skin Market
# 97        101                            Vocal Biomarkers Market
# 98        102                          Car T Cell Therapy Market
# 99        103  Negative Pressure Wound Therapy (NPWT) Devices...
#
#    Forecast Period      Market Size Year  \
# 0     2025 to 2032  Market Size in 2025:
# 1     2025 to 2032  Market Size in 2025:
# 2     2025 to 2032  Market Size in 2025:
# 3     2025 to 2032  Market Size in 2025:
# 4     2025 to 2032  Market Size in 2025:
# ..             ...                   ...
# 95    2025 to 2032  Market Size in 2025:
# 96    2025 to 2032  Market Size in 2025:
# 97    2025 to 2032  Market Size in 2025:
# 98    2025 to 2032  Market Size in 2025:
# 99    2025 to 2032  Market Size in 2025:
#
#                                           Market Size   CAGR  \
# 0                       nan; Market Size in 2032: nan    NaN
# 1                       nan; Market Size in 2032: nan    NaN
# 2                       nan; Market Size in 2032: nan    NaN
# 3                       nan; Market Size in 2032: nan    NaN
# 4      USD 7.56 Bn; Market Size in 2032: USD 14.38 Bn  0.096
# ..                                                ...    ...
# 95                      nan; Market Size in 2032: nan    NaN
# 96                      nan; Market Size in 2032: nan    NaN
# 97                      nan; Market Size in 2032: nan    NaN
# 98     USD 3.99 Bn; Market Size in 2032: USD 15.06 Bn  0.209
# 99  USD 2,763.8 Mn; Market Size in 2032: USD 4,294...  0.065
#
#                                           Key Players  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4   Air Methods Corporation, Deccan Charters, Scan...
# ..                                                ...
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
# 98  Bristol-Myers Squibb Company, Johnson &amp; Jo...
# 99  3M, Cardinal Health, Smith+Nephew, Genadyne, D...
#
#                                                Prompt
# 0   Furthermore, we have a CTA that needs to be in...
# 1   Furthermore, we have a CTA that needs to be in...
# 2   Furthermore, we have a CTA that needs to be in...
# 3   Furthermore, we have a CTA that needs to be in...
# 4   Furthermore, we have a CTA that needs to be in...
# ..                                                ...
# 95  Furthermore, we have a CTA that needs to be in...
# 96  Furthermore, we have a CTA that needs to be in...
# 97  Furthermore, we have a CTA that needs to be in...
# 98  Furthermore, we have a CTA that needs to be in...
# 99  Furthermore, we have a CTA that needs to be in...
#
# [100 rows x 8 columns]

# %%
# Assuming output_df is the DataFrame you want to save
output_df.to_excel('final.xlsx', index=False)
