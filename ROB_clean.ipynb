# %% [markdown]
# <a href="https://colab.research.google.com/github/7717CMI/Automate/blob/main/ROB_clean.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Define column names
columns = ['Report ID', 'Report Name', 'Report URL', 'Publish Date', 'Companies', 'Segments', 'Base Year',
           'Market Size Year 2025', 'Historical Data', 'CAGR', 'Forecast Period', 'Value Projection 2032', 'Description']

# Create a list of data
data = [
    [82, 'Elderly And Disabled Assistive Devices Market',
     'https://www.coherentmarketinsights.com/market-insight/elderly-and-disabled-assistive-devices-market-82',
     '12-Feb-25',
     'AI Squared, Drive Medical, GN Resound Group, Invacare, Nordic Capital, Pride Mobility Products Corporation, Siemens Ltd., Sonova Holding AG, Starkey hearing technologies, William Demant Holding A/S, GF Health Products, Inc., Magic Mobility Ltd., MEYRA GmbH, Audina Hearing Instruments, Inc., Handicare Group AB, Enabling Technologies',
     'By Device Type: Medical Mobility Aids and Ambulatory Devices, Medical Furniture and Bathroom Safety Products, Hearing Aids, Vision and Reading Aids\nBy End User: Hospital, Home Care Settings, Nursing Homes, Assisted Living Facilities, Others',
     2024, 'USD 30.32 Bn', '2020 To 2024', '7.90%', '2025 To 2032', 'USD 51.67 Bn',
     'Elderly And Disabled Assistive Devices Market is estimated to be valued at USD 30.32 Bn in 2025 and is expected to reach USD 51.67 Bn by 2032, growing at a compound annual growth rate (CAGR) of 7.9% from 2025 to 2032.\n\nFigure. Elderly And Disabled Assistive Devices Market Share (%), By Region 2025 https://www.coherentmarketinsights.com/images/research-%20methodology/elderly-and-disabled-assistive-devices-market-regional-insights.webp'],

    [83, 'Blood Processing Devices and Consumables Market',
     'https://www.coherentmarketinsights.com/market-insight/blood-processing-devices-and-consumables-market-83',
     '10-Mar-25',
     'Beckman Coulter, Inc., Thermogenesis Holdings, Inc., Maco Pharma International GmbH, Immucor, Inc., Becton, Dickinson and Company, Bio-Rad Laboratories, Inc., Grifols, S.A., Abbott Laboratories, Global Scientific Company, Sigma Laborzentrifugen GmbH, Terumo BCT, Inc., Poly Medicure Ltd, and Thermo Fisher Scientific, Inc.',
     'By Product Type: Devices (Plasma Freezers, Blood Bank Refrigerators, Lab Refrigerators, Lab Freezers, Ultralow Temperatures, Shock Freezers, Grouping Analyzers, Warmers, Hematocrit Centrifuges, Cell Processors), Consumables (Blood Administration Sets, Blood Bags, Blood Collection Needles, Blood Collection Tube, Blood Filters, Blood Lancets, Blood Grouping Reagents, Blood Coagulation Reagents, Hematology Reagents, Slides, Sedimentation Tubes, Slide Stainer, Test Tube Racks, Vials)\nBy End User: Hospitals and Clinics, Diagnostic Laboratories, Others',
     2024, 'USD 52.03 Bn', '2020 To 2024', '6.70%', '2025 To 2032', 'USD 81.92 Bn',
     'Blood Processing Devices and Consumables Market is estimated to be valued at USD 52.03 Bn in 2025 and is expected to reach USD 81.92 Bn by 2032, growing at a compound annual growth rate (CAGR) of 6.7% from 2025 to 2032.\n\nFigure. Blood Processing Devices And Consumables Market Share (%), By Region 2025 https://www.coherentmarketinsights.com/images/research-%20methodology/66350global-blood-processing-devices-and-consumables-market-figure-1.png'],

    [84, 'Deep Brain Stimulation Devices Market',
     'https://www.coherentmarketinsights.com/market-insight/deep-brain-stimulation-devices-market-84',
     '26-Feb-25',
     'Abbott, Medtronic, Boston Scientific Corporation, Neuropace Inc., LivaNova Plc, Renishaw Plc, Aleva Neurotherapeutics S.A., Beijing Pinchi Medical Equipment Co. Ltd, Nexstim, St. Jude Medical (now part of Abbott), Cyberonics (now part of LivaNova), EBR Systems, IntraPace, Nevro Corp, and Stimwave Technologies',
     'By Product Type: Single-channel DBS Devices and Dual-channel DBS Devices\nBy Application: Epilepsy, Pain Management, Essential Tremor, Obsessive Compulsive Disorder (OCD), Parkinson’s Disease, Depression, Dystonia, and Others\nBy End User: Hospitals, Neurology Clinics, Ambulatory Surgical Centers, Research Centers, and Others',
     2024, 'US$ 1.66 Bn', '2020 To 2024', '10.70%', '2025 To 2032', 'US$ 3.38 Bn',
     'Deep Brain Stimulation Devices Market is estimated to be valued at US$ 1.66 Bn in 2025 and is expected to reach US$ 3.38 Bn by 2032, growing at a compound annual growth rate (CAGR) of 10.7% from 2025 to 2032.\n\nFigure. Deep Brain Stimulation Devices Market Share (%), By Region 2025 https://www.coherentmarketinsights.com/images/research-%20methodology/deep-brain-stimulation-devices-market-regional-insights.webp'],

    [85, 'Dental Equipment Market',
     'https://www.coherentmarketinsights.com/market-insight/dental-equipment-market-85',
     '6-Feb-25',
     '3M, Dentsply Sirona, Straumann, Danaher Corporation, Henry Schein, Zimmer Biomet, Planmeca, Ivoclar Vivadent, GC Corporation, Biolase Inc., Carestream Health, A-dec Inc., Midmark Corporation, Vatech Co. Ltd., and Nobel Biocare',
     'By Product: General and Diagnostic Equipment (Dental Laser), Dental Consumables, and Other Dental Devices\nBy Treatment: Orthodontic, Endodontic, Periodontic, and Prosthodontic\nBy End User: Hospitals, Dental Clinics, Dental Laboratories, and Research Institutions',
     2024, 'USD 12.11 Bn', '2020 To 2024', '6.60%', '2025 To 2032', 'USD 18.96 Bn',
     'Dental Equipment Market is estimated to be valued at USD 12.11 Bn in 2025 and is expected to reach USD 18.96 Bn by 2032, growing at a compound annual growth rate (CAGR) of 6.6% from 2025 to 2032.\n\nFigure. Dental Equipment Market Share (%), By Region 2025 https://www.coherentmarketinsights.com/images/research-%20methodology/dental-equipment-market-regional-insights.webp'],

    [102, 'Car T Cell Therapy Market',
     'https://www.coherentmarketinsights.com/market-insight/car-t-cell-therapy-market-102',
     '10-Mar-25',
     'Bristol-Myers Squibb Company, Johnson & Johnson Services, Inc., Novartis AG, CARsgenTherapeutics Co., Ltd, Aurora Biopharma, Legend Biotech, Gilead Sciences, Inc., Pfizer Inc., bluebird bio, Inc., Sorrento Therapeutics, Inc., Mustang Bio, Fate Therapeutics',
     'By Targeted Antigen: CD19, BCMA, HER2, GD2, CD20, CD22, CD30, CD33, HER1, Others (CLDN18, etc.)\nBy Therapeutic Application: Acute Lymphocytic Leukemia, Chronic Lymphocytic Leukemia, Diffuse Large B-cell Lymphoma (DLBCL), Follicular Lymphoma, Mantle Cell Lymphoma, Multiple Myeloma, Glioblastoma, Sarcoma, Neuroblastoma, Acute Myeloid Leukemia, Breast Cancer, Pancreatic Cancer, Hepatocellular Carcinoma, Colorectal Cancer, Others (Gastric Cancer, etc.)',
     2024, 'USD 3.99 Bn', '2020 To 2024', '20.90%', '2025 To 2032', 'USD 15.06 Bn',
     'Car T Cell Therapy Market is estimated to be valued at USD 3.99 Bn in 2025 and is expected to reach USD 15.06 Bn by 2032, growing at a compound annual growth rate (CAGR) of 20.9% from 2025 to 2032.\n\nFigure. Car T Cell Therapy Market Share (%), By Region 2025 https://www.coherentmarketinsights.com/images/research-%20methodology/206981car-t-cell-therapy-market-figure-1.png'],

    [103, 'Negative Pressure Wound Therapy (NPWT) Devices Market',
     'https://www.coherentmarketinsights.com/market-insight/negative-pressure-wound-therapy-devices-market-103',
     '10-Mar-25',
     '3M, Cardinal Health, Smith+Nephew, Genadyne, DeRoyal Industries, Inc., Medela AG, Convatec Inc., Mölndycke Health Care AB, PAUL HARTMANN AG, ATMOS MedizinTechnik GmbH & Co. KG, Talley Group Ltd, Cork Medical, LLC, and Devon Medical Products',
     'By Product Type: Single-use NPWT Devices, Conventional NPWT Devices\nBy Application: Diabetic Foot Ulcers, Pressure Ulcers, Venous Leg Ulcers, Burn Wounds, Others (Surgical Wounds, Traumatic Wounds, etc.)\nBy End User: Hospitals, Home Care Settings, Others (Ambulatory Surgery Centers (ASCs), Specialty Clinics, etc.)',
     2024, 'USD 2,763.8 Mn', '2020 To 2024', '6.50%', '2025 To 2032', 'USD 4,294.9 Mn',
     'Negative Pressure Wound Therapy (NPWT) Devices Market is estimated to be valued at USD 2,763.8 Mn in 2025 and is expected to reach USD 4,294.9 Mn by 2032, growing at a compound annual growth rate (CAGR) of 6.5% from 2025 to 2032.\n\nFigure. Negative Pressure Wound Therapy (NPWT) Devices Market Share (%), By Region 2025 https://www.coherentmarketinsights.com/images/research-%20methodology/11341global-negative-pressure-wound-therapy-npwt-devices-market-figure-1.png'],

    [104, 'Breast Lesion Localization Methods Market',
     'https://www.coherentmarketinsights.com/market-insight/breast-lesion-localization-methods-market-104',
     '2-Jun-25',
     'Cook Medical Incorporated, C.R. Bard Inc., Endomagnetics Ltd., SOMATEX Medical Technologies GmbH., Cianna Medical, Argon Medical Devices Inc., Hologic Inc., and STERYLAB.',
     'By Lesion Type: Non-palpable Lesions, Palpable lesions, Microcalcifications, Others (Ductal Carcinoma in Situ, among others)\nBy Procedure Type: Wire Localization, Radioisotope Localization, Magnetic Tracer, Radiofrequency Localization, Others (Clip Placement, among others)\nBy Technology: Radioactive, Magnetic, Radiofrequency, Others (Blue Dye Localization, among others)\nBy End User: Hospitals, Diagnostic Centers, Ambulatory Care Centers, Others (Private Clinics, among others)',
     2024, 'USD 461.5 Mn', '2020 To 2024', '7.60%', '2025 To 2032', 'USD 770.7 Mn',
     'Breast Lesion Localization Methods Market is estimated to be valued at USD 461.5 Mn in 2025 and is expected to reach USD 770.7 Mn by 2032, growing at a compound annual growth rate (CAGR) of 7.6% from 2025 to 2032.\n\nFigure. Breast Lesion Localization Methods Market Share (%), By Region 2025 https://www.coherentmarketinsights.com/images/research-%20methodology/846480global-breast-lesion-localization-methods-market-figure-1.png']
]

# Create a pandas DataFrame with the given values
df = pd.DataFrame(data, columns=columns)

# Display the DataFrame
print(df)
# Out:
#    Report ID                                        Report Name  \
# 0         82      Elderly And Disabled Assistive Devices Market
# 1         83    Blood Processing Devices and Consumables Market
# 2         84              Deep Brain Stimulation Devices Market
# 3         85                            Dental Equipment Market
# 4        102                          Car T Cell Therapy Market
# 5        103  Negative Pressure Wound Therapy (NPWT) Devices...
# 6        104          Breast Lesion Localization Methods Market
#
#                                           Report URL Publish Date  \
# 0  https://www.coherentmarketinsights.com/market-...    12-Feb-25
# 1  https://www.coherentmarketinsights.com/market-...    10-Mar-25
# 2  https://www.coherentmarketinsights.com/market-...    26-Feb-25
# 3  https://www.coherentmarketinsights.com/market-...     6-Feb-25
# 4  https://www.coherentmarketinsights.com/market-...    10-Mar-25
# ...

# %%
# !pip install pandas
import pandas as pd
from google.colab import data_table


# Enable the interactive display
data_table.enable_dataframe_formatter()

# Display the DataFrame using data_table
df
# Out:
# ...
#    Report ID                                        Report Name  \
# 0         82      Elderly And Disabled Assistive Devices Market
# 1         83    Blood Processing Devices and Consumables Market
# 2         84              Deep Brain Stimulation Devices Market
# 3         85                            Dental Equipment Market
# 4        102                          Car T Cell Therapy Market
# 5        103  Negative Pressure Wound Therapy (NPWT) Devices...
# 6        104          Breast Lesion Localization Methods Market
#
#                                           Report URL Publish Date  \
# 0  https://www.coherentmarketinsights.com/market-...    12-Feb-25
# 1  https://www.coherentmarketinsights.com/market-...    10-Mar-25
# 2  https://www.coherentmarketinsights.com/market-...    26-Feb-25
# 3  https://www.coherentmarketinsights.com/market-...     6-Feb-25
# 4  https://www.coherentmarketinsights.com/market-...    10-Mar-25
# ...

# %%
# Drop the specified columns
columns_to_drop = ['Report URL', 'Publish Date', 'Segments', 'Base Year', 'Historical Data', 'Description']
df = df.drop(columns=columns_to_drop)

# Display the updated DataFrame
print(df)
# Out:
#    Report ID                                        Report Name  \
# 0         82      Elderly And Disabled Assistive Devices Market
# 1         83    Blood Processing Devices and Consumables Market
# 2         84              Deep Brain Stimulation Devices Market
# 3         85                            Dental Equipment Market
# 4        102                          Car T Cell Therapy Market
# 5        103  Negative Pressure Wound Therapy (NPWT) Devices...
# 6        104          Breast Lesion Localization Methods Market
#
#                                            Companies Market Size Year 2025  \
# 0  AI Squared, Drive Medical, GN Resound Group, I...          USD 30.32 Bn
# 1  Beckman Coulter, Inc., Thermogenesis Holdings,...          USD 52.03 Bn
# 2  Abbott, Medtronic, Boston Scientific Corporati...           US$ 1.66 Bn
# 3  3M, Dentsply Sirona, Straumann, Danaher Corpor...          USD 12.11 Bn
# 4  Bristol-Myers Squibb Company, Johnson & Johnso...           USD 3.99 Bn
# ...

# %%
# !pip install pandas
import pandas as pd
from google.colab import data_table


# Enable the interactive display
data_table.enable_dataframe_formatter()

# Display the DataFrame using data_table
df
# Out:
# ...
#    Report ID                                        Market Name  \
# 0         82      Elderly And Disabled Assistive Devices Market
# 1         83    Blood Processing Devices and Consumables Market
# 2         84              Deep Brain Stimulation Devices Market
# 3         85                            Dental Equipment Market
# 4        102                          Car T Cell Therapy Market
# 5        103  Negative Pressure Wound Therapy (NPWT) Devices...
# 6        104          Breast Lesion Localization Methods Market
#
#                                          Key Players Market Size Year 2025  \
# 0  AI Squared, Drive Medical, GN Resound Group, I...          USD 30.32 Bn
# 1  Beckman Coulter, Inc., Thermogenesis Holdings,...          USD 52.03 Bn
# 2  Abbott, Medtronic, Boston Scientific Corporati...           US$ 1.66 Bn
# 3  3M, Dentsply Sirona, Straumann, Danaher Corpor...          USD 12.11 Bn
# 4  Bristol-Myers Squibb Company, Johnson & Johnso...           USD 3.99 Bn
# ...

# %%
# Rename the specified columns
df = df.rename(columns={
    'Report Name': 'Market Name',
    'Companies': 'key Players'
})

# Display the updated DataFrame with renamed columns
print(df)
# Out:
#    Report ID                                        Market Name  \
# 0         82      Elderly And Disabled Assistive Devices Market
# 1         83    Blood Processing Devices and Consumables Market
# 2         84              Deep Brain Stimulation Devices Market
# 3         85                            Dental Equipment Market
# 4        102                          Car T Cell Therapy Market
# 5        103  Negative Pressure Wound Therapy (NPWT) Devices...
# 6        104          Breast Lesion Localization Methods Market
#
#                                          Key Players Market Size Year 2025  \
# 0  AI Squared, Drive Medical, GN Resound Group, I...          USD 30.32 Bn
# 1  Beckman Coulter, Inc., Thermogenesis Holdings,...          USD 52.03 Bn
# 2  Abbott, Medtronic, Boston Scientific Corporati...           US$ 1.66 Bn
# 3  3M, Dentsply Sirona, Straumann, Danaher Corpor...          USD 12.11 Bn
# 4  Bristol-Myers Squibb Company, Johnson & Johnso...           USD 3.99 Bn
# ...

# %%
# Enable the interactive display
data_table.enable_dataframe_formatter()

# Display the DataFrame using data_table
df
# Out:
#    Report ID                                        Market Name  \
# 0         82      Elderly And Disabled Assistive Devices Market
# 1         83    Blood Processing Devices and Consumables Market
# 2         84              Deep Brain Stimulation Devices Market
# 3         85                            Dental Equipment Market
# 4        102                          Car T Cell Therapy Market
# 5        103  Negative Pressure Wound Therapy (NPWT) Devices...
# 6        104          Breast Lesion Localization Methods Market
#
#                                          Key Players Market Size Year 2025  \
# 0  AI Squared, Drive Medical, GN Resound Group, I...          USD 30.32 Bn
# 1  Beckman Coulter, Inc., Thermogenesis Holdings,...          USD 52.03 Bn
# 2  Abbott, Medtronic, Boston Scientific Corporati...           US$ 1.66 Bn
# 3  3M, Dentsply Sirona, Straumann, Danaher Corpor...          USD 12.11 Bn
# 4  Bristol-Myers Squibb Company, Johnson & Johnso...           USD 3.99 Bn
# ...

# %%
# Add the new columns with constant values
df['Market Size Year'] = 'Market Size in 2025:'
df['Forecast Period'] = '2025 to 2032'

# Display the updated DataFrame with the new columns
print(df)
# Out:
#    Report ID                                        Market Name  \
# 0         82      Elderly And Disabled Assistive Devices Market
# 1         83    Blood Processing Devices and Consumables Market
# 2         84              Deep Brain Stimulation Devices Market
# 3         85                            Dental Equipment Market
# 4        102                          Car T Cell Therapy Market
# 5        103  Negative Pressure Wound Therapy (NPWT) Devices...
# 6        104          Breast Lesion Localization Methods Market
#
#                                          Key Players Market Size Year 2025  \
# 0  AI Squared, Drive Medical, GN Resound Group, I...          USD 30.32 Bn
# 1  Beckman Coulter, Inc., Thermogenesis Holdings,...          USD 52.03 Bn
# 2  Abbott, Medtronic, Boston Scientific Corporati...           US$ 1.66 Bn
# 3  3M, Dentsply Sirona, Straumann, Danaher Corpor...          USD 12.11 Bn
# 4  Bristol-Myers Squibb Company, Johnson & Johnso...           USD 3.99 Bn
# ...

# %%
# Enable the interactive display
data_table.enable_dataframe_formatter()

# Display the DataFrame using data_table
df
# Out:
#    Report ID                                        Market Name  \
# 0         82      Elderly And Disabled Assistive Devices Market
# 1         83    Blood Processing Devices and Consumables Market
# 2         84              Deep Brain Stimulation Devices Market
# 3         85                            Dental Equipment Market
# 4        102                          Car T Cell Therapy Market
# 5        103  Negative Pressure Wound Therapy (NPWT) Devices...
# 6        104          Breast Lesion Localization Methods Market
#
#                                          Key Players Market Size Year 2025  \
# 0  AI Squared, Drive Medical, GN Resound Group, I...          USD 30.32 Bn
# 1  Beckman Coulter, Inc., Thermogenesis Holdings,...          USD 52.03 Bn
# 2  Abbott, Medtronic, Boston Scientific Corporati...           US$ 1.66 Bn
# 3  3M, Dentsply Sirona, Straumann, Danaher Corpor...          USD 12.11 Bn
# 4  Bristol-Myers Squibb Company, Johnson & Johnso...           USD 3.99 Bn
# ...

# %%
# Define the desired column order
desired_order = ['Report ID', 'Market Name', 'Forecast Period', 'Market Size Year', 'Value Projection 2032', 'CAGR', 'Key Players',]

# Reorder the DataFrame columns
df = df[desired_order]

# Display the updated DataFrame with the new column order
print(df)
# Out:
#    Report ID                                        Market Name  \
# 0         82      Elderly And Disabled Assistive Devices Market
# 1         83    Blood Processing Devices and Consumables Market
# 2         84              Deep Brain Stimulation Devices Market
# 3         85                            Dental Equipment Market
# 4        102                          Car T Cell Therapy Market
# 5        103  Negative Pressure Wound Therapy (NPWT) Devices...
# 6        104          Breast Lesion Localization Methods Market
#
#   Forecast Period      Market Size Year Value Projection 2032    CAGR  \
# 0    2025 to 2032  Market Size in 2025:          USD 51.67 Bn   7.90%
# 1    2025 to 2032  Market Size in 2025:          USD 81.92 Bn   6.70%
# 2    2025 to 2032  Market Size in 2025:           US$ 3.38 Bn  10.70%
# 3    2025 to 2032  Market Size in 2025:          USD 18.96 Bn   6.60%
# 4    2025 to 2032  Market Size in 2025:          USD 15.06 Bn  20.90%
# ...

# %%
# Enable the interactive display
data_table.enable_dataframe_formatter()

# Display the DataFrame using data_table
df
# Out:
#    Report ID                                        Market Name  \
# 0         82      Elderly And Disabled Assistive Devices Market
# 1         83    Blood Processing Devices and Consumables Market
# 2         84              Deep Brain Stimulation Devices Market
# 3         85                            Dental Equipment Market
# 4        102                          Car T Cell Therapy Market
# 5        103  Negative Pressure Wound Therapy (NPWT) Devices...
# 6        104          Breast Lesion Localization Methods Market
#
#   Forecast Period      Market Size Year Value Projection 2032    CAGR  \
# 0    2025 to 2032  Market Size in 2025:          USD 51.67 Bn   7.90%
# 1    2025 to 2032  Market Size in 2025:          USD 81.92 Bn   6.70%
# 2    2025 to 2032  Market Size in 2025:           US$ 3.38 Bn  10.70%
# 3    2025 to 2032  Market Size in 2025:          USD 18.96 Bn   6.60%
# 4    2025 to 2032  Market Size in 2025:          USD 15.06 Bn  20.90%
# ...

# %%
# Add the "Market Size Year 2025" column with the provided values
market_size_values = ['USD 30.32 Bn', 'USD 52.03 Bn', 'US$ 1.66 Bn', 'USD 12.11 Bn', 'USD 3.99 Bn', 'USD 2,763.8 Mn', 'USD 461.5 Mn']
df['Market Size Year 2025'] = market_size_values

# Display the updated DataFrame
print(df)
# Out:
#    Report ID                                        Market Name  \
# 0         82      Elderly And Disabled Assistive Devices Market
# 1         83    Blood Processing Devices and Consumables Market
# 2         84              Deep Brain Stimulation Devices Market
# 3         85                            Dental Equipment Market
# 4        102                          Car T Cell Therapy Market
# 5        103  Negative Pressure Wound Therapy (NPWT) Devices...
# 6        104          Breast Lesion Localization Methods Market
#
#   Forecast Period      Market Size Year Value Projection 2032    CAGR  \
# 0    2025 to 2032  Market Size in 2025:          USD 51.67 Bn   7.90%
# 1    2025 to 2032  Market Size in 2025:          USD 81.92 Bn   6.70%
# 2    2025 to 2032  Market Size in 2025:           US$ 3.38 Bn  10.70%
# 3    2025 to 2032  Market Size in 2025:          USD 18.96 Bn   6.60%
# 4    2025 to 2032  Market Size in 2025:          USD 15.06 Bn  20.90%
# ...

# %%
# Enable the interactive display
data_table.enable_dataframe_formatter()

# Display the DataFrame using data_table
df
# Out:
#    Report ID                                        Market Name  \
# 0         82      Elderly And Disabled Assistive Devices Market
# 1         83    Blood Processing Devices and Consumables Market
# 2         84              Deep Brain Stimulation Devices Market
# 3         85                            Dental Equipment Market
# 4        102                          Car T Cell Therapy Market
# 5        103  Negative Pressure Wound Therapy (NPWT) Devices...
# 6        104          Breast Lesion Localization Methods Market
#
#   Forecast Period      Market Size Year Value Projection 2032    CAGR  \
# 0    2025 to 2032  Market Size in 2025:          USD 51.67 Bn   7.90%
# 1    2025 to 2032  Market Size in 2025:          USD 81.92 Bn   6.70%
# 2    2025 to 2032  Market Size in 2025:           US$ 3.38 Bn  10.70%
# 3    2025 to 2032  Market Size in 2025:          USD 18.96 Bn   6.60%
# 4    2025 to 2032  Market Size in 2025:          USD 15.06 Bn  20.90%
# ...

# %%
# Define the desired column order
desired_order = ['Report ID', 'Market Name', 'Forecast Period', 'Market Size Year','Market Size Year 2025','Value Projection 2032', 'CAGR', 'Key Players', ]

# Reorder the DataFrame columns
df = df[desired_order]

# Display the updated DataFrame with the new column order
print(df)
# Out:
#    Report ID                                        Market Name  \
# 0         82      Elderly And Disabled Assistive Devices Market
# 1         83    Blood Processing Devices and Consumables Market
# 2         84              Deep Brain Stimulation Devices Market
# 3         85                            Dental Equipment Market
# 4        102                          Car T Cell Therapy Market
# 5        103  Negative Pressure Wound Therapy (NPWT) Devices...
# 6        104          Breast Lesion Localization Methods Market
#
#   Forecast Period      Market Size Year Market Size Year 2025  \
# 0    2025 to 2032  Market Size in 2025:          USD 30.32 Bn
# 1    2025 to 2032  Market Size in 2025:          USD 52.03 Bn
# 2    2025 to 2032  Market Size in 2025:           US$ 1.66 Bn
# 3    2025 to 2032  Market Size in 2025:          USD 12.11 Bn
# 4    2025 to 2032  Market Size in 2025:           USD 3.99 Bn
# 5    2025 to 2032  Market Size in 2025:        USD 2,763.8 Mn
# ...

# %%
# Enable the interactive display
data_table.enable_dataframe_formatter()

# Display the DataFrame using data_table
df
# Out:
#    Report ID                                        Market Name  \
# 0         82      Elderly And Disabled Assistive Devices Market
# 1         83    Blood Processing Devices and Consumables Market
# 2         84              Deep Brain Stimulation Devices Market
# 3         85                            Dental Equipment Market
# 4        102                          Car T Cell Therapy Market
# 5        103  Negative Pressure Wound Therapy (NPWT) Devices...
# 6        104          Breast Lesion Localization Methods Market
#
#   Forecast Period      Market Size Year Market Size Year 2025  \
# 0    2025 to 2032  Market Size in 2025:          USD 30.32 Bn
# 1    2025 to 2032  Market Size in 2025:          USD 52.03 Bn
# 2    2025 to 2032  Market Size in 2025:           US$ 1.66 Bn
# 3    2025 to 2032  Market Size in 2025:          USD 12.11 Bn
# 4    2025 to 2032  Market Size in 2025:           USD 3.99 Bn
# 5    2025 to 2032  Market Size in 2025:        USD 2,763.8 Mn
# ...

# %%
# Create the new column "Market Size" by combining the values from "Market Size Year 2025" and "Value Projection 2032"
df['Market Size'] = df['Market Size Year 2025'] + ' ; Market Size in 2032: ' + df['Value Projection 2032']

# Drop the old columns "Value Projection 2032" and "Market Size Year 2025"
df = df.drop(columns=['Value Projection 2032', 'Market Size Year 2025'])

# Display the updated DataFrame
print(df)
# Out:
#    Report ID                                        Market Name  \
# 0         82      Elderly And Disabled Assistive Devices Market
# 1         83    Blood Processing Devices and Consumables Market
# 2         84              Deep Brain Stimulation Devices Market
# 3         85                            Dental Equipment Market
# 4        102                          Car T Cell Therapy Market
# 5        103  Negative Pressure Wound Therapy (NPWT) Devices...
# 6        104          Breast Lesion Localization Methods Market
#
#   Forecast Period      Market Size Year    CAGR  \
# 0    2025 to 2032  Market Size in 2025:   7.90%
# 1    2025 to 2032  Market Size in 2025:   6.70%
# 2    2025 to 2032  Market Size in 2025:  10.70%
# 3    2025 to 2032  Market Size in 2025:   6.60%
# 4    2025 to 2032  Market Size in 2025:  20.90%
# 5    2025 to 2032  Market Size in 2025:   6.50%
# 6    2025 to 2032  Market Size in 2025:   7.60%
#
#                                          Key Players  \
# ...

# %%
# Enable the interactive display
data_table.enable_dataframe_formatter()

# Display the DataFrame using data_table
df
# Out:
#    Report ID                                        Market Name  \
# 0         82      Elderly And Disabled Assistive Devices Market
# 1         83    Blood Processing Devices and Consumables Market
# 2         84              Deep Brain Stimulation Devices Market
# 3         85                            Dental Equipment Market
# 4        102                          Car T Cell Therapy Market
# 5        103  Negative Pressure Wound Therapy (NPWT) Devices...
# 6        104          Breast Lesion Localization Methods Market
#
#   Forecast Period      Market Size Year    CAGR  \
# 0    2025 to 2032  Market Size in 2025:   7.90%
# 1    2025 to 2032  Market Size in 2025:   6.70%
# 2    2025 to 2032  Market Size in 2025:  10.70%
# 3    2025 to 2032  Market Size in 2025:   6.60%
# 4    2025 to 2032  Market Size in 2025:  20.90%
# 5    2025 to 2032  Market Size in 2025:   6.50%
# 6    2025 to 2032  Market Size in 2025:   7.60%
#
#                                          Key Players  \
# ...

# %%
# Define the desired column order
desired_order = ['Report ID', 'Market Name', 'Forecast Period', 'Market Size Year','Market Size', 'CAGR', 'Key Players', ]

# Reorder the DataFrame columns
df = df[desired_order]

# Display the updated DataFrame with the new column order
print(df)
# Out:
#    Report ID                                        Market Name  \
# 0         82      Elderly And Disabled Assistive Devices Market
# 1         83    Blood Processing Devices and Consumables Market
# 2         84              Deep Brain Stimulation Devices Market
# 3         85                            Dental Equipment Market
# 4        102                          Car T Cell Therapy Market
# 5        103  Negative Pressure Wound Therapy (NPWT) Devices...
# 6        104          Breast Lesion Localization Methods Market
#
#   Forecast Period      Market Size Year  \
# 0    2025 to 2032  Market Size in 2025:
# 1    2025 to 2032  Market Size in 2025:
# 2    2025 to 2032  Market Size in 2025:
# 3    2025 to 2032  Market Size in 2025:
# 4    2025 to 2032  Market Size in 2025:
# 5    2025 to 2032  Market Size in 2025:
# 6    2025 to 2032  Market Size in 2025:
#
#                                          Market Size    CAGR  \
# ...

# %%
# Enable the interactive display
data_table.enable_dataframe_formatter()

# Display the DataFrame using data_table
df
# Out:
#    Report ID                                        Market Name  \
# 0         82      Elderly And Disabled Assistive Devices Market
# 1         83    Blood Processing Devices and Consumables Market
# 2         84              Deep Brain Stimulation Devices Market
# 3         85                            Dental Equipment Market
# 4        102                          Car T Cell Therapy Market
# 5        103  Negative Pressure Wound Therapy (NPWT) Devices...
# 6        104          Breast Lesion Localization Methods Market
#
#   Forecast Period      Market Size Year  \
# 0    2025 to 2032  Market Size in 2025:
# 1    2025 to 2032  Market Size in 2025:
# 2    2025 to 2032  Market Size in 2025:
# 3    2025 to 2032  Market Size in 2025:
# 4    2025 to 2032  Market Size in 2025:
# 5    2025 to 2032  Market Size in 2025:
# 6    2025 to 2032  Market Size in 2025:
#
#                                          Market Size    CAGR  \
# ...
