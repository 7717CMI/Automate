# %%
from docx import Document

# Load the DOCX file
doc_path = 'ROB_Smartphone.docx'
doc = Document(doc_path)

# Extract all text from the document and store it in a string
saved = "\n".join([para.text for para in doc.paragraphs])

# Print the content stored in 'saved'
print(saved)
# Out:
# Version 1
# ___________________________________________________________________________
#
#
#
#
# Hello! How can I assist you today?
# _______________________________________________________________________
#
# Version 2
# _______________________________________________________________________
#
#
#
#
#
# _________________________________________________________________________
#
# Version 3
# _________________________________________________________________________
#
#
# _________________________________________________________________________
#
# V4
#
# __________________________________________________________________________
#
#
# **Global Smartphone Market Size, Trends, Growth, and Forecast Analysis 2025-2032**
#
# ...

# %%
first_saved = saved.split()[-9]
print(first_saved)

# useful: index from 20 to -9
# Out:
# opportunities.

# %%
start_phrase = saved.split()[21] # The start of the text you're looking for
end_phrase = saved.split()[-9] # The end of the text you're looking for


print(start_phrase)
print(end_phrase)
# Out:
# **Global
# opportunities.

# %%
start_phrase = saved.split()[21] # The start of the text you're looking for
end_phrase = saved.split()[-9] # The end of the text you're looking for

start_index = 21  # Find the index where the start_phrase appears
end_index = -9 # Find the index where the end_phrase appears


# Extract the chunk of text between start and end
if start_index != -1 and end_index != -1:
    chunk = saved[start_index:end_index]
    print(chunk)
else:
    print("Text not found.")

# Split the string into words
#first_word = chunk.split()[-2]
#end_word = chunk.split()[-7]
# Out:
# ________________________________________________________________
#
#
#
#
# Hello! How can I assist you today?
# _______________________________________________________________________
#
# Version 2
# _______________________________________________________________________
#
#
#
#
#
# _________________________________________________________________________
#
# Version 3
# _________________________________________________________________________
#
#
# _________________________________________________________________________
#
# V4
#
# __________________________________________________________________________
#
#
# **Global Smartphone Market Size, Trends, Growth, and Forecast Analysis 2025-2032**
#
# ...

# %%
words = saved.split()
start_index = 21
end_index = -8

# Extract the chunk of text between start and end
if len(words) > abs(end_index):
    chunk = " ".join(words[start_index:end_index])
    print(chunk)
else:
    print("Text not found.")
# Out:
# **Global Smartphone Market Size, Trends, Growth, and Forecast Analysis 2025-2032** The smartphone industry remains a pivotal sector driving digital transformation worldwide, characterized by rapid technological advancements and evolving consumer preferences. The continuous integration of 5G, AI capabilities, and enhanced camera systems fuel an intensely competitive landscape marked by swift innovation cycles and dynamic business growth. ### Market Size and Overview The Global Smartphone Market size is estimated to be valued at USD 520 billion in 2025 and is expected to reach USD 740 billion by 2032, exhibiting a compound annual growth rate (CAGR) of 5.1% from 2025 to 2032. This robust market forecast underscores the sustained demand driven by emerging economies, technological upgrades, and rising consumer spending. Recent market analysis highlights significant shifts toward premium models and diversified user segments contributing notably to market revenue expansion. ### Key Takeaway
# ...
